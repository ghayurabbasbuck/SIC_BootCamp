# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('elections.csv')

# %%
df
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
df.shape
# Out:
# (182, 6)

# %%
print(df.columns)
# Out:
# Index(['Year', 'Candidate', 'Party', 'Popular vote', 'Result', '%'], dtype='object')

# %%
print(df['Candidate'])
# Out:
# 0         Andrew Jackson
# 1      John Quincy Adams
# 2         Andrew Jackson
# 3      John Quincy Adams
# 4         Andrew Jackson
#              ...
# 177           Jill Stein
# 178         Joseph Biden
# 179         Donald Trump
# 180         Jo Jorgensen
# 181       Howard Hawkins
# Name: Candidate, Length: 182, dtype: object

# %%
df[df['Year'] == 1828]
# Out:
#    Year          Candidate                Party  Popular vote Result  \
# 2  1828     Andrew Jackson           Democratic        642806    win
# 3  1828  John Quincy Adams  National Republican        500897   loss
#
#            %
# 2  56.203927
# 3  43.796073

# %%
df.loc[df['Party'] == 'Democratic']
# Out:
#      Year               Candidate       Party  Popular vote Result          %
# 2    1828          Andrew Jackson  Democratic        642806    win  56.203927
# 4    1832          Andrew Jackson  Democratic        702735    win  54.574789
# 8    1836        Martin Van Buren  Democratic        763291    win  52.272472
# 10   1840        Martin Van Buren  Democratic       1128854   loss  46.948787
# 13   1844              James Polk  Democratic       1339570    win  50.749477
# 14   1848              Lewis Cass  Democratic       1223460   loss  42.552229
# 17   1852         Franklin Pierce  Democratic       1605943    win  51.013168
# 20   1856          James Buchanan  Democratic       1835140    win  45.306080
# 28   1864     George B. McClellan  Democratic       1812807   loss  45.048488
# 29   1868         Horatio Seymour  Democratic       2708744   loss  47.334695
# 34   1876        Samuel J. Tilden  Democratic       4288546   loss  51.528376
# ...

# %%
df.loc[df['Result']=='win',['Year','Popular vote']]
# Out:
#      Year  Popular vote
# 1    1824        113142
# 2    1828        642806
# 4    1832        702735
# 8    1836        763291
# 11   1840       1275583
# 13   1844       1339570
# 16   1848       1360235
# 17   1852       1605943
# 20   1856       1835140
# 23   1860       1855993
# 27   1864       2211317
# 30   1868       3013790
# 32   1872       3597439
# 33   1876       4034142
# 36   1880       4453337
# 39   1884       4914482
# 43   1888       5443633
# 47   1892       5553898
# 53   1896       7112138
# 56   1900       7228864
# 60   1904       7630557
# 65   1908       7678335
# 70   1912       6296284
# 74   1916       9126868
# 79   1920      16144093
# 80   1924      15723789
# 84   1928      21427123
# 86   1932      22821277
# 91   1936      27752648
# 94   1940      27313945
# 97   1944      25612916
# 100  1948      24179347
# 106  1952      34075529
# 109  1956      35579180
# 111  1960      34220984
# 114  1964      43127041
# 117  1968      31783783
# ...

# %%
df.loc[df['Year']==1828]
# Out:
#    Year          Candidate                Party  Popular vote Result  \
# 2  1828     Andrew Jackson           Democratic        642806    win
# 3  1828  John Quincy Adams  National Republican        500897   loss
#
#            %
# 2  56.203927
# 3  43.796073

# %%
df.loc[df['%'] > 55]
# Out:
#      Year           Candidate                  Party  Popular vote Result  \
# 0    1824      Andrew Jackson  Democratic-Republican        151271   loss
# 2    1828      Andrew Jackson             Democratic        642806    win
# 32   1872       Ulysses Grant             Republican       3597439    win
# 60   1904  Theodore Roosevelt             Republican       7630557    win
# 79   1920      Warren Harding             Republican      16144093    win
# 84   1928      Herbert Hoover             Republican      21427123    win
# 86   1932  Franklin Roosevelt             Democratic      22821277    win
# 91   1936  Franklin Roosevelt             Democratic      27752648    win
# 106  1952   Dwight Eisenhower             Republican      34075529    win
# 109  1956   Dwight Eisenhower             Republican      35579180    win
# 114  1964      Lyndon Johnson             Democratic      43127041    win
# 120  1972       Richard Nixon             Republican      47168710    win
# ...

# %%
df.iloc[:5,:]
# Out:
#    Year          Candidate                  Party  Popular vote Result  \
# 0  1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824  John Quincy Adams  Democratic-Republican        113142    win
# 2  1828     Andrew Jackson             Democratic        642806    win
# 3  1828  John Quincy Adams    National Republican        500897   loss
# 4  1832     Andrew Jackson             Democratic        702735    win
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789

# %%
df.iloc[1:5,:3]
# Out:
#    Year          Candidate                  Party
# 1  1824  John Quincy Adams  Democratic-Republican
# 2  1828     Andrew Jackson             Democratic
# 3  1828  John Quincy Adams    National Republican
# 4  1832     Andrew Jackson             Democratic

# %%
df.iloc[:10,[3,4]]
# Out:
#    Popular vote Result
# 0        151271   loss
# 1        113142    win
# 2        642806    win
# 3        500897   loss
# 4        702735    win
# 5        484205   loss
# 6        100715   loss
# 7        146109   loss
# 8        763291    win
# 9        550816   loss

# %%
df.loc[(df['Result'] == 'loss') & (df['%']<50)]
# Out:
#      Year               Candidate                Party  Popular vote Result  \
# 3    1828       John Quincy Adams  National Republican        500897   loss
# 5    1832              Henry Clay  National Republican        484205   loss
# 6    1832            William Wirt         Anti-Masonic        100715   loss
# 7    1836       Hugh Lawson White                 Whig        146109   loss
# 9    1836  William Henry Harrison                 Whig        550816   loss
# ..    ...                     ...                  ...           ...    ...
# 176  2016         Hillary Clinton           Democratic      65853514   loss
# 177  2016              Jill Stein                Green       1457226   loss
# 179  2020            Donald Trump           Republican      74216154   loss
# 180  2020            Jo Jorgensen          Libertarian       1865724   loss
# 181  2020          Howard Hawkins                Green        405035   loss
#
#              %
# 3    43.796073
# 5    37.603628
# ...

# %%
df.loc[df['Candidate'].isin(['Democratic','Republican']) & df['Result']=='won']
# Out:
# Empty DataFrame
# Columns: [Year, Candidate, Party, Popular vote, Result, %]
# Index: []

# %% [markdown]
# # QUIZ

# %% [markdown]
# ### Using loc

# %% [raw]
# 1.  Extract all rows for the candidate 'Andrew Jackson' and display the columns 'Year',
# 'Popular vote', and 'Result'

# %%
df.loc[df['Candidate']=='Andrew Jackson',['Year','Popular vote','Result']]
# Out:
#    Year  Popular vote Result
# 0  1824        151271   loss
# 2  1828        642806    win
# 4  1832        702735    win

# %% [raw]
# 2. Use `loc` to extract all rows where the candidate's `Party` is 'Democratic' and display
# the 'Year', 'Candidate', and 'Result'.

# %%
df.loc[df['Party'] == 'Democratic',['Year','Candidate','Result']]
# Out:
#      Year               Candidate Result
# 2    1828          Andrew Jackson    win
# 4    1832          Andrew Jackson    win
# 8    1836        Martin Van Buren    win
# 10   1840        Martin Van Buren   loss
# 13   1844              James Polk    win
# 14   1848              Lewis Cass   loss
# 17   1852         Franklin Pierce    win
# 20   1856          James Buchanan    win
# 28   1864     George B. McClellan   loss
# 29   1868         Horatio Seymour   loss
# 34   1876        Samuel J. Tilden   loss
# 37   1880  Winfield Scott Hancock   loss
# 39   1884        Grover Cleveland    win
# 45   1888        Grover Cleveland   loss
# 47   1892        Grover Cleveland    win
# 52   1896  William Jennings Bryan   loss
# 55   1900  William Jennings Bryan   loss
# 57   1904         Alton B. Parker   loss
# 64   1908  William Jennings Bryan   loss
# 70   1912          Woodrow Wilson    win
# 74   1916          Woodrow Wilson    win
# 77   1920            James M. Cox   loss
# ...

# %% [raw]
# 3. Extract rows where the `Popular vote` is greater than 600000 and display the
# 'Candidate' and 'Party' columns.
